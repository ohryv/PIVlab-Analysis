# %%
import numpy as np
import matplotlib as mpl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.cbook as cbook
import matplotlib.image as image
import math

# The goal of this notebook is to be able to plot where vortices have the highest probability of forming

# %%
def about():
    about = '''Utilities for plotting the preferrential areas for vortex formation.
    IMPORTANT CRITERIA:
    - Data must all be FROM THE SAME EXPERIMENT
    - Vortex data must be COLLECTED SEPARATELY and SAVED AS A CSV FILE.
    - The columns must be in a certain order due to assumptions made by the program. The names do not have to be the same as the sample (to account
    for units)
    '''
    print(about)

# %%
testdata = "Input/Vortex Probability/Vortices - Catie Thesis Simplified Px.csv"
testimg =

# %%
#Testing overlaying images over plots
file = "C:/Users/oksan/Downloads/SSR 2026/Small Tank Trials/6.25.26 Run 3 Polyps Open/polypsopen_100pc_6.25.26_run3_500fps_C001H001S0001/polypsopen_100pc_6.25.26_run3_500fps_C001H001S0001000001.bmp"
im = image.imread(file)

## Display information about the image
print(f"Image shape: {im.shape}")
print(f"Image data type: {im.dtype}")

## Display the image
plt.figure()
plt.imshow(im)
plt.axis('off')  ## Hide axis
plt.title('Sample Image')
plt.show()


## Create a figure and axes for our plot
fig, ax = plt.subplots(figsize=(1024, 1280, "px"))

## Set a random seed for reproducibility
np.random.seed(19680801)

## Generate random data
x = np.arange(30)  ## x-axis values (0 to 29)
y = x + np.random.randn(30)  ## y-axis values (x plus random noise)

## Create a bar chart
bars = ax.bar(x, y, color='#6bbc6b')  ## Green bars

## Add grid lines
ax.grid(linestyle='--', alpha=0.7)

## Add labels and title
ax.set_xlabel('X-axis Label')
ax.set_ylabel('Y-axis Label')
ax.set_title('Bar Chart with Random Data')

## Get figure dimensions
fig_width, fig_height = fig.get_size_inches() * fig.dpi

## Calculate center position (this is approximate)
x_center = fig_width / 2 - im.shape[1] / 2
y_center = fig_height / 2 - im.shape[0] / 2

#Plot the image
fig.figimage(im, x_center, y_center, zorder=3, alpha=0.3)

## Display the plot
plt.tight_layout()
plt.show()
# Out:
# Image shape: (1024, 1280, 3)
# Image data type: uint8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 18
#      14 plt.show()
#      15
#      16
#      17 ## Create a figure and axes for our plot
# ---> 18 fig, ax = plt.subplots(figsize=(1024, 1280, "px"))
#      19
#      20 ## Set a random seed for reproducibility
#      21 np.random.seed(19680801)
#
# File ~\anaconda3\envs\SSR_2026\Lib\site-packages\matplotlib\pyplot.py:1776, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1621 def subplots(
#    1622     nrows: int = 1, ncols: int = 1, *,
#    1623     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)   1630     **fig_kw
#    1631 ) -> tuple[Figure, Any]:
#    1632     """
#    1633     Create a figure and a set of subplots.
#    1634
#    (...)   1774
# ...

# %%
about()
# Out:
#  Utilities for plotting the preferrential areas for vortex formation.
#     IMPORTANT CRITERIA:
#     - Data must all be FROM THE SAME EXPERIMENT
#     - Vortex data must be COLLECTED SEPARATELY and SAVED AS A CSV FILE.
#     - The columns must be in a certain order due to assumptions made by the program. The names do not have to be the same as the sample (to account
#     for units)
